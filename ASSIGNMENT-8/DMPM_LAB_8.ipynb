# %% [markdown]
# <a href="https://colab.research.google.com/github/24cseaiml040nilamanikundu/DMPM_LAB/blob/main/ASSIGNMENT-8/DMPM_LAB_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.array([1,2,3,4])
y = np.array([2,3,4,5])
sum_x = sum(x)
sum_y = sum(y)
sum_xy = sum(x * y)
sum_x2 = sum(x**2)
sum_y2 = sum(y**2)
n = len(x)

r = (n * sum_xy - sum_x * sum_y) / (np.sqrt((n * sum_x2 - sum_x**2) * (n * sum_y2 - sum_y**2)))
print(f"The Correlation Coefficient is: {r:.4f}")

x_mean = np.mean(x)
y_mean = np.mean(y)
covariance = np.sum((x - x_mean) * (y - y_mean)) / (n - 1)
print(f"The Covariance is: {covariance:.4f}")
# Out:
# The Correlation Coefficient is: 1.0000
# The Covariance is: 1.6667

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/RajeshRanaGiet/DMPM-Lab/main/Experiment%208/Salary_dataset.csv")
x = np.array(data["YearsExperience"])
y = np.array(data["Salary"])

sum_x = sum(x)
sum_y = sum(y)
sum_xy = sum(x * y)
sum_x2 = sum(x**2)
sum_y2 = sum(y**2)
n = len(x)

r = (n * sum_xy - sum_x * sum_y) / (np.sqrt((n * sum_x2 - sum_x**2) * (n * sum_y2 - sum_y**2)))
print(f"The Correlation Coefficient is: {r:.4f}")

x_mean = np.mean(x)
y_mean = np.mean(y)
covariance = np.sum((x - x_mean) * (y - y_mean)) / (n - 1)
print(f"The Covariance is: {covariance:.4f}")
# Out:
# The Correlation Coefficient is: 0.9782
# The Covariance is: 76106.3034
